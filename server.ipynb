# %%
import flask 
from flask import Flask,request, render_template
from fastai.vision import *
import pickle
import DB

app=Flask(__name__)
api=Api(app)



@app.route('/')
@app.route('/index')
def index():
  return flask.render_template('index.html')


@app.route('/predict', methods=['GET','POST'])
def upload_file():
  if request.method=='POST':
    f=request.files['file'])
    predict_img=User(predict_img='f')
    
    prediction=model.predict(predict_img)
    prediction=str(prediction)

    return render_template('index.html',ml_label=label)


if __name__=='__main__':
  app.debug=True
  db.creaste_all()
  app.secret_key="123"
  model=joblib.load('./peoplespace/export.pkl')
  app.run(host='0.0.0.0', port=8000, debug=True)
# Out:
#   File "<ipython-input-1-1b83d24e3fca>", line 6
#     from disease_module import
#                                ^
# SyntaxError: invalid syntax
